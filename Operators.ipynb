# %% [markdown]
# ## Artimethic Operator

# %% [markdown]
# Suma

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# Multiplicación

# %%
 4 * 5
# Out:
# 20

# %% [markdown]
# Potencia.

# %%
5 ** 2
# Out:
# 25

# %% [markdown]
# División

# %%
20 / 5
# Out:
# 4.0

# %%
20/6
# Out:
# 3.3333333333333335

# %% [markdown]
# Da un número flotante de un valor entero, cada vez que hagas una dvisión, obtendrás un valor flotante o decimal. Esto se debe a que es posible que no siempre se obtenga un número entero para la división

# %% [markdown]
# El operador de módulo le da el resto después de cualquier división.

# %% [markdown]
# Por ejemplo, si hago 20 módulos 6, obtengo 2 porque 20, dado que 20 divido por 6 es 18 con un resto de 2.

# %%
20 % 6
# Out:
# 2

# %% [markdown]
# % es la operación de módulo, la cual aparece mucho en la programación.

# %% [markdown]
# Arithmetic Operators with Strings.

# %% [markdown]
# Sumas con cadenas.

# %%
'string 1' + ' string 2'
# Out:
# 'string 1 string 2'

# %% [markdown]
# Multiplicaciones con cadenas

# %%
' - string 1 -' * 4
# Out:
# ' - string 1 - - string 1 - - string 1 - - string 1 -'

# %% [markdown]
# Prestar atención a los tipos de variables con las que estamos trabajando

# %% [markdown]
# Comparison, Logical, and Membership Operators.

# %% [markdown]
# Todos estos operadores evalúan dos variables o valores y producen un valor booleano, verdadero o falso

# %% [markdown]
# Comparison Operators

# %% [markdown]
# Es el doble signo igual el operador de comparación.

# %%
True == True
# Out:
# True

# %%
4 < 5
# Out:
# True

# %%
4 <= 5
# Out:
# True

# %%
5 > 2
# Out:
# True

# %%
5 >= 2
# Out:
# True

# %% [markdown]
# Logical operators (and, or, not)

# %% [markdown]
# Los operadores lógicos son en realidad simples palabras en ingles. Operan en booleanos, y existen tres operadores lógicos.

# %% [markdown]
# Con el operador and, ambos lados tienen que ser verdaderos.

# %%
True and True
# Out:
# True

# %% [markdown]
# El operador or, verdadero o falso,

# %%
True or False
# Out:
# True

# %% [markdown]
# El operador not, que es el que opera en una sola cosa a la vez, y simplemente voltea el booleano en el que está operando.

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# Simplemente invirte lo que sea esta variable

# %% [markdown]
# Membership Operators

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
10 in [1,2,3]
# Out:
# False

# %%
10 not in [1,2,3]
# Out:
# True

# %%
'cat' in 'my cat is here'
# Out:
# True

# %%
'book' in 'Library'
# Out:
# False

# %% [markdown]
# Ten cuidado cuando uses este truco en Python cuando se trate de cadenas.
